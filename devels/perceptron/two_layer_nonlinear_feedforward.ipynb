# %% [markdown]
# # two-layer non-linear feedforward

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2
import ipynb.fs.full.model as nn

xr = [0, 20, 2]; yr = [0, 10, 1];
cs = [2, 3, -30]
xx, yy, zz = ds2.linear_separable(
    xr, yr, cs)
ds2.plot_dataset(plt, xx, yy, zz)

wi = [4, -5, 10]
xb, yb = nn.decision_boundary(
    xr, yr, wi)
plt.plot(xb, yb, 'g--', lw=2);
plt.show()

# %%
data = [xx, yy, zz]

wi = [4, -5, 10]
alpha = 0.01; epoch = 500

w1, w2, b, sse, mce = nn.slp_learn_err(
    data, wi, alpha, epoch)

plt.figure(figsize=(4,4))
plt.plot(w1)
plt.plot(w2)
plt.plot(b)
plt.legend(['w1', 'w2', 'b'])
plt.xlabel('epoch');
plt.ylabel('params')
plt.grid(); plt.show()

# %%
plt.figure(figsize=(4,4))
plt.plot(sse)
plt.legend(['sse'])
plt.xlabel('epoch');
plt.ylabel('errors')
plt.grid(); plt.show()

print('sse =', sse[-1])

# %%
plt.figure(figsize=(4,4))
plt.plot(mce)
plt.legend(['mce'])
plt.xlabel('epoch');
plt.ylabel('errors')
plt.grid(); plt.show()

print('mce =', mce[-1])

# %%
ds2.plot_dataset(plt, xx, yy, zz)

wf = [w1[-1], w2[-1], b[-1]]
xb, yb = nn.decision_boundary(
    xr, yr, wf)
plt.plot(xb, yb, 'g--', lw=2);
plt.show()

# %%
import ipynb.fs.full.model as nn
import numpy as np

w = [1, 2, 3]
x = [1, 1]
y = nn.perceptron_f(w, x, nn.binary_step)
print(y)

w = [1, 2, 3]
x = [1, 1]
y = nn.perceptron_f(w, x, np.tanh)
print(y)
# Out:
# 1
# 0.9999877116507956

# %%
import ipynb.fs.full.datasets2 as ds2
import ipynb.fs.full.model as nn
import numpy as np
import matplotlib.pyplot as plt

xr = [0, 20]; yr = [0, 20];
w = [1, 0, -10]
xx1, yy1, zz1 = nn.predicted_data_f(
    xr, yr, w, nn.binary_step)

ds2.plot_dataset(plt, xx1, yy1, zz1)

# %%
import ipynb.fs.full.datasets2 as ds2
import ipynb.fs.full.model as nn
import numpy as np
import matplotlib.pyplot as plt

xr = [0, 20]; yr = [0, 20];
w = [0, 1, -10]
xx2, yy2, zz2 = nn.predicted_data_f(
    xr, yr, w, nn.binary_step)

ds2.plot_dataset(plt, xx2, yy2, zz2)

# %%
import ipynb.fs.full.datasets2 as ds2
import ipynb.fs.full.model as nn
import numpy as np
import matplotlib.pyplot as plt
import math

xr = [0, 20]; yr = [0, 20];
w = [0, 1, -10]
xx3, yy3, zz3 = nn.predicted_data_f(
    xr, yr, w, math.tanh)

print(zz3)
ds2.plot_dataset(plt, xx3, yy3, zz3)
# Out:
# [-0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.9999999958776927, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.999999969540041, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999997749296758, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999983369439447, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999877116507956, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.9999092042625951, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.999329299739067, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9950547536867305, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.9640275800758169, -0.7615941559557649, -0.7615941559557649, -0.7615941559557649, -0.761594 ...
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# Cell In[6], line 13
#       9 xx3, yy3, zz3 = nn.predicted_data_f(
#      10     xr, yr, w, math.tanh)
#      12 print(zz3)
# ---> 13 ds2.plot_dataset(plt, xx3, yy3, zz3)
#
# File M:\pasir\devels\perceptron\datasets2.ipynb:31, in plot_dataset(plt, x, y, z)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "539d4f57-499e-4015-b1d6-112cea78c0e7",
#       6    "metadata": {},
#       7    "source": [
#       8     "# dataset2 for linearly separable problems"
#       9    ]
#      10   },
#      11   {
#      12    "cell_type": "code",
#      13    "execution_count": null,
#      14    "id": "2b371b38-86da-4d85-b132-b72910f1fe9b",
#      15    "metadata": {},
#      16    "outputs": [],
#      17    "source": [
#      18     "def linear_separable(xrange, yrange, coeffs):\n",
#      19     "    xmin = xrange[0]; xmax = xrange[1]; dx = xrange[2]\n",
#      20     "    ymin = yrange[0]; ymax = yrange[1]; dy = yrange[2]\n",
#      21     "    a = coeffs[0]; b = coeffs[1]; c = coeffs[2]\n",
#      22     "    xx = []; yy = []; zz = []\n",
#      23     "    for y in range(ymin, ymax+dy, dy):\n",
#      24     "        for x in range(xmin, xmax+dx, dx):\n",
#      25     "            xx.append(x)\n",
#      26     "            yy.append(y)\n",
#      27     "            if a*x + b*y + c >= 0:\n",
#      28     "                zz.append(1)\n",
#      29     "            else:\n",
#      30     "                zz.append(0)\n",
# ---> 31     "    return (xx, yy, zz)"
#      32    ]
#      33   },
#      34   {
#      35    "cell_type": "code",
#      36    "execution_count": null,
#      37    "id": "e05b0080-60cf-4c96-8b69-401f272fdc15",
#      38    "metadata": {},
#      39    "outputs": [],
#      40    "source": [
#      41     "def plot_dataset(plt, x, y, z):\n",
#      42     "    import matplotlib.pyplot as plt\n",
#      43     "    styles = ['s','o']\n",
#      44     "    fill = ['#ddf', '#fdd']; stroke = ['b', 'r']\n",
#      45     "    plt.figure(figsize=(4, 4))\n",
#      46     "    \n",
#      47     "    for i in range(len(x)):\n",
#      48     "        m = styles[z[i]]\n",
#      49     "        mec = stroke[z[i]]; mfc = fill[z[i]]\n",
#      50     "        plt.plot(x[i], y[i], marker=m, mec=mec, mfc=mfc)\n",
#      51     "    \n",
#      52     "    plt.xlabel('x1')\n",
#      53     "    plt.ylabel('x2')\n",
#      54     "    plt.grid();"
#      55    ]
#      56   },
#      57   {
#      58    "cell_type": "code",
#      59    "execution_count": null,
#      60    "id": "1754ea52-ee78-4340-ae81-456aff04b2f9",
#      61    "metadata": {},
#      62    "outputs": [],
#      63    "source": []
#      64   }
#      65  ],
#      66  "metadata": {
#      67   "kernelspec": {
#      68    "display_name": "Python 3 (ipykernel)",
#      69    "language": "python",
#      70    "name": "python3"
#      71   },
#      72   "language_info": {
#      73    "codemirror_mode": {
#      74     "name": "ipython",
#      75     "version": 3
#      76    },
#      77    "file_extension": ".py",
#      78    "mimetype": "text/x-python",
#      79    "name": "python",
#      80    "nbconvert_exporter": "python",
#      81    "pygments_lexer": "ipython3",
#      82    "version": "3.12.3"
#      83   }
#      84  },
#      85  "nbformat": 4,
#      86  "nbformat_minor": 5
#      87 }
#
# TypeError: list indices must be integers or slices, not float
